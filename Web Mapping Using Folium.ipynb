# %% [markdown]
# # **Python Web Mapping Using Folium.**

# %% [markdown]
# **Table of Contents.**
#
# 1. Introduction.
# 2. Install and import modules.
# 3. Data cleaning and exploration.
# 4. Folium Maps.
#
#     4.1. A basic folium map.
#
#     4.2. Loaction markers.
#
#     4.3. Cirle Markers.
#
#     4.4. GeoJson layer.
#
#     4.5. Minimap.
#
#     4.6. Search bar.
#
#     4.7. Terminator.
#
#     4.8. Routes.
#
#     4.9. Ant Routes.
#
#     4.10. Cluster Markers.
#
#     4.11. Heatmaps.
#
#     4.12. Choropleth Map.
#
#     4.13. Coordinates Tool.
#
#     4.14. Measure Tool.
#
#     4.15. Dual Map.
#
# 5. References.
#
# # 1. Introduction.
#
# Interactive geographic maps provide a better view of hidden information in data. These maps allow users to interact through features such as : zooming in and out, selecting layers, panning and clickable data points. By stackin multiple layers geographic content, one can display massive complex data and share them widely as a website.
# Using a Python's Folium library, we are able to access free and open source Leaflet JavaScript library through an API.
# Leaflet js is used to dispaly simple, light weight and interactive maps online as layer such as : markers, popups, GeoJson, image overlays, WMS, and vector data types.
#  We will build maps by exploring major Africa cities.

# %% [markdown]
# # 2. Install and import modules.

# %%
# Install modules
# !pip install mapclassify geopandas pandas folium

# Import modules
import geopandas as gpd            # Read geojson and shapefile
import pandas as pd                # Read csv file
import folium                      # Web maps
from mapclassify import classify    # web maps
from folium import plugins         # Extends folium functionality

# %% [markdown]
# # 3. Explore Data.
#
# We need to load data into our workspace from Google Colab and perform data analysis. Since raw data contains uneccessary noise i.e. unwanted columns, we are going to clean it and finally convert the geojson countries file to geodataframe.

# %%
# Read datasets

# African countries in geojson format
ctry = gpd.read_file(r'/content/africa-countries.geojson')

# Worldcities in csv.
cities = pd.read_csv(r'/content/worldcities.csv')

# %% [markdown]
# Explore countries ppolygon data.

# %%
# View all columns of a dataframe
pd.set_option('display.max_columns', None)
print(ctry.columns)
# Out:
# Index(['scalerank', 'featurecla', 'labelrank', 'sovereignt', 'sov_a3',
#        'adm0_dif', 'level', 'type', 'admin', 'adm0_a3', 'geou_dif', 'geounit',
#        'gu_a3', 'su_dif', 'subunit', 'su_a3', 'brk_diff', 'name', 'name_long',
#        'brk_a3', 'brk_name', 'brk_group', 'abbrev', 'postal', 'formal_en',
#        'formal_fr', 'note_adm0', 'note_brk', 'name_sort', 'name_alt',
#        'mapcolor7', 'mapcolor8', 'mapcolor9', 'mapcolor13', 'pop_est',
#        'gdp_md_est', 'pop_year', 'lastcensus', 'gdp_year', 'economy',
#        'income_grp', 'wikipedia', 'fips_10', 'iso_a2', 'iso_a3', 'iso_n3',
#        'un_a3', 'wb_a2', 'wb_a3', 'woe_id', 'adm0_a3_is', 'adm0_a3_us',
#        'adm0_a3_un', 'adm0_a3_wb', 'continent', 'region_un', 'subregion',
#        'region_wb', 'name_len', 'long_len', 'abbrev_len', 'tiny', 'homepart',
#        'filename', 'geometry'],
#       dtype='object')

# %%
# Subset columns from african countries data
africa = ctry[['admin', 'income_grp', 'iso_a3', 'pop_est','subregion', 'region_wb', 'geometry']]

# Rename iso_a3 column to iso3
africa.rename(columns = {'iso_a3':'iso3'}, inplace=True)

# %%
# Find if there is any duplicate values

any(africa.duplicated())
# Out:
# False

# %%
# View a subset of the cleaned dataframe, the first
africa.head(5)
# Out:
#                               admin              income_grp iso3   pop_est  \
# 0                           Burundi           5. Low income  BDI   8988091
# 1                             Benin           5. Low income  BEN   8791832
# 2                      Burkina Faso           5. Low income  BFA  15746232
# 3                       Ivory Coast  4. Lower middle income  CIV  20617068
# 4  Democratic Republic of the Congo           5. Low income  COD  68692542
#
#         subregion           region_wb  \
# 0  Eastern Africa  Sub-Saharan Africa
# 1  Western Africa  Sub-Saharan Africa
# 2  Western Africa  Sub-Saharan Africa
# 3  Western Africa  Sub-Saharan Africa
# 4   Middle Africa  Sub-Saharan Africa
#
#                                             geometry
# 0  POLYGON ((29.34000 -4.49998, 29.27638 -3.29391...
# 1  POLYGON ((2.69170 6.25882, 1.86524 6.14216, 1....
# 2  POLYGON ((-2.82750 9.64246, -3.51190 9.90033, ...
# 3  POLYGON ((-2.85613 4.99448, -3.31108 4.98430, ...
# 4  POLYGON ((30.83386 3.50917, 30.77335 2.33988, ...

# %%
# Create a simple web map of countries data

africa.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5e1a1d944312b5a047657dd4522a6e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5e1a1d944312b5a047657dd4522a6e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5e1a1d944312b5a047657dd4522a6e9 = L.map(
#                 &quot;map_f5e1a1d944312b5a047657dd4522a6e9&quot;,
#                 {
#                     center: [1.2654139999999998, 16.7544135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f5e1a1d944312b5a047657dd4522a6e9);
#
#
#
#
#
#             var tile_layer_599662c8a0e48f029aa027a8a4f4c1b1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f5e1a1d944312b5a047657dd4522a6e9);
#
#
#             map_f5e1a1d944312b5a047657dd4522a6e9.fitBounds(
#                 [[-34.819166, -17.625043], [37.349994, 51.13387]],
#                 {}
#             );
#
#
#         function geo_json_90c859f04f3324cfaefb06bb9b118106_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_90c859f04f3324cfaefb06bb9b118106_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_90c859f04f3324cfaefb06bb9b118106_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_90c859f04f3324cfaefb06bb9b118106_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_90c859f04f3324cfaefb06bb9b118106_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_90c859f04f3324cfaefb06bb9b118106.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_90c859f04f3324cfaefb06bb9b118106_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_90c859f04f3324cfaefb06bb9b118106 = L.geoJson(null, {
#                 onEachFeature: geo_json_90c859f04f3324cfaefb06bb9b118106_onEachFeature,
#
#                 style: geo_json_90c859f04f3324cfaefb06bb9b118106_styler,
#                 pointToLayer: geo_json_90c859f04f3324cfaefb06bb9b118106_pointToLayer
#         });
#
#         function geo_json_90c859f04f3324cfaefb06bb9b118106_add (data) {
#             geo_json_90c859f04f3324cfaefb06bb9b118106
#                 .addData(data)
#                 .addTo(map_f5e1a1d944312b5a047657dd4522a6e9);
#         }
#             geo_json_90c859f04f3324cfaefb06bb9b118106_add({&quot;bbox&quot;: [-17.625043, -34.819166, 51.13387, 37.349994], &quot;features&quot;: [{&quot;bbox&quot;: [29.024926, -4.499983, 30.752263, -2.348487], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[29.339998, -4.499983], [29.276384, -3.293907], [29.024926, -2.839258], [29.632176, -2.917858], [29.938359, -2.348487], [30.469696, -2.413858], [30.527677, -2.807632], [30.743013, -3.034285], [30.752263, -3.35933], [30.50556, -3.568567], [30.116333, -4.090138], [29.753512, -4.452389], [29.339998, -4.499983]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;admin&quot;: &quot;Burundi&quot;, &quot;income_grp&quot;: &quo

# %% [markdown]
# Explore cities data.

# %%
# Data exploration world cities data

print(cities.columns)
# Out:
# Index(['city', 'city_ascii', 'lat', 'lng', 'country', 'iso2', 'iso3',
#        'admin_name', 'capital', 'population', 'id'],
#       dtype='object')

# %%
# Convert cities data to geodataframe

cities = gpd.GeoDataFrame(cities,                                                    # Data
                          geometry = gpd.points_from_xy(cities.lng, cities.lat),     # columns containing location infrormation
                          crs = 4326)

# %%
# Filter primary cities that are also found in our african polygon dataset.

african_cities_pop = cities[((cities['capital'] == 'primary') & (cities.iso3.isin(list(africa.iso3))))]
# Out:
# 67

# %% [markdown]
# Subset data , filter only primary cities in Africa and select needed columns.

# %%
# Filter primary cities that are also found in our african polygon dataset.
african_cities_pop = cities[(cities['capital'] == 'primary') & (cities.iso3.isin(list(africa.iso3)))]

# Select important columns.
african_cities_pop = african_cities_pop[['city_ascii', 'lat', 'lng', 'country', 'iso3', 'population', 'geometry']]

# View data
african_cities_pop
# Out:
# 67
#         city_ascii      lat      lng           country iso3  population  \
# 10           Cairo  30.0444  31.2358             Egypt  EGY  19787000.0
# 19           Lagos   6.4500   3.4000           Nigeria  NGA  15487000.0
# 22        Kinshasa  -4.3317  15.3139  Congo (Kinshasa)  COD  15056000.0
# 47          Luanda  -8.8383  13.2344            Angola  AGO   8883000.0
# 68   Dar es Salaam  -6.8000  39.2833          Tanzania  TZA   7461000.0
# ..             ...      ...      ...               ...  ...         ...
# 783        Mbabane -26.3208  31.1617         Swaziland  SWZ     94874.0
# 795         Gitega  -3.4283  29.9250           Burundi  BDI     41944.0
# 801         Banjul  13.4531 -16.5775        The Gambia  GMB     31356.0
# 824        Lobamba -26.4465  31.2064         Swaziland  SWZ      5800.0
# 849       Tifariti  26.0928 -10.6089           Morocco  MAR         NaN
#
#                        geometry
# 10    POINT (31.23580 30.04440)
# 19      POINT (3.40000 6.45000)
# 22    POINT (15.31390 -4.33170)
# 47    POINT (13.23440 -8.83830)
# 68    POINT (39.28330 -6.80000)
# ..                          ...
# 783  POINT (31.16170 -26.32080)
# 795   POINT (29.92500 -3.42830)
# 801  POINT (-16.57750 13.45310)
# 824  POINT (31.20640 -26.44650)
# 849  POINT (-10.60890 26.09280)
#
# [67 rows x 7 columns]

# %% [markdown]
# # 4. Folium maps.
#
# **4.1 A basic folium map.**
#
# Lets create a basic folium map with

# %%
# Create folium map with different basemaps

# Make an empty map
map = folium.Map(location=[5, 24],     # Approximate central location for africa
                 tiles="Stamen Watercolor",  # Add base map
               zoom_start=3,         # Low zoom level less detail, zoomed in.
               width=900,             # Map Pixel size horizontally
               height=600,            # Map Pixel size vertically
               control_scale = True   # Adds distance scale
              )

# add different tiles/basemaps to map which users can select or unselect any layer
folium.raster_layers.TileLayer('CartoDB Positron').add_to(map)
folium.raster_layers.TileLayer('Open Street Map').add_to(map)
folium.raster_layers.TileLayer('CartoDB Dark_Matter').add_to(map)
folium.raster_layers.TileLayer('Stamen Terrain').add_to(map)
folium.raster_layers.TileLayer('Stamen Toner').add_to(map)

# add layer control , allow toggling of layers.
folium.LayerControl().add_to(map)

# Show map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6cd713ec67d98b8c03392094a3dd59b {
#                     position: relative;
#                     width: 900.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6cd713ec67d98b8c03392094a3dd59b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6cd713ec67d98b8c03392094a3dd59b = L.map(
#                 &quot;map_d6cd713ec67d98b8c03392094a3dd59b&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d6cd713ec67d98b8c03392094a3dd59b);
#
#
#
#
#
#             var tile_layer_5cfdd93431d7fb29a79f15ad608cebfd = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d6cd713ec67d98b8c03392094a3dd59b);
#
#
#             var tile_layer_654b6003f8f379389949e5e57bfea85e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d6cd713ec67d98b8c03392094a3dd59b);
#
#
#             var tile_layer_af867e3577e32e1c1f823be14525a413 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d6cd713ec67d98b8c03392094a3dd59b);
#
#
#             var tile_layer_ebfa8917a547f8fe0a48f23dbff7e31f = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d6cd713ec67d98b8c03392094a3dd59b);
#
#
#             var tile_layer_a0219e299517e657bee25a9b60888c46 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d6cd713ec67d98b8c03392094a3dd59b);
#
#
#             var tile_laye

# %% [markdown]
# **4.2. Loaction markers.**
#
# Each marker has a pop up that when clicked will display city name and its corresponding population.

# %%
# Add locations marker to major african cities with each pop up showing city and its population.

for index, location_info in african_cities_pop .iterrows():

    # Add marker to each location
    folium.Marker([location_info.lat, location_info.lng],
                  # Pop up shows city and population message when clicked.
                  popup=location_info.city_ascii +' ' + str(location_info.population)).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba867efad77a62497f0e168c67d15732 {
#                     position: relative;
#                     width: 900.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba867efad77a62497f0e168c67d15732&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba867efad77a62497f0e168c67d15732 = L.map(
#                 &quot;map_ba867efad77a62497f0e168c67d15732&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ba867efad77a62497f0e168c67d15732);
#
#
#
#
#
#             var tile_layer_9fe7a0fecce586026c91521f00304a65 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ba867efad77a62497f0e168c67d15732);
#
#
#             var marker_212df655c2c5fb7f59ee5d5531a66b94 = L.marker(
#                 [30.0444, 31.2358],
#                 {}
#             ).addTo(map_ba867efad77a62497f0e168c67d15732);
#
#
#         var popup_fd8d38dac0319b43173d1597194ea093 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_13ac799aab96f204915e87e73e791507 = $(`&lt;div id=&quot;html_13ac799aab96f204915e87e73e791507&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cairo 19787000.0&lt;/div&gt;`)[0];
#                 popup_fd8d38dac0319b43173d1597194ea093.setContent(html_13ac799aab96f204915e87e73e791507);
#
#
#
#         marker_212df655c2c5fb7f59ee5d5531a66b94.bindPopup(popup_fd8d38dac0319b43173d1597194ea093)
#         ;
#
#
#
#
#             var marker_5c1103d8545c695aa3f8aa9e534bc617 = L.marker(
#                 [6.45, 3.4],
#                 {}
#             ).addTo(map_ba867efad77a62497f0e168c67d15732);
#
#
#         var popup_86001ea7f0a220673442fb611e86f907 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9bbe5da8bbe22289e5438bbf8fac948c = $(`&lt;div id=&quot;html_9bbe5da8bbe22289e5438bbf8fac948c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lagos 15487000.0&lt;/div&gt;`)[0];
#                 popup_86001ea7f0a220673442fb611e86f907.setContent(html_9bbe5da8bbe22289e5438bbf8fac948c);
#
#
#
#         marker_5c1103d8545c695aa3f8aa9e534bc617.bindPopup(popup_86001ea7f0a220673442fb611e86f907)
#         ;
#
#
#
#
#             var marker_a42541c910ed64972771cf6cae032266 = L.marker(
#                 [-4.3317, 15.3139],
#                 {}
#             ).addTo(map_ba867efad77a62497f0e168c67d15732);
#
#
#         var popup_d0fb62271fe4e9f4d5e51bdb4fdfcd01 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c63f24b1fab466cd9d5e24015dcca0a4 = $(`&lt;div id=&quot;html_c63f24b1fab466cd9d5e24015dcca0a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kinshasa 15056000.0&lt;/div&gt;`)[0];
#                 popup_d0fb62271fe4e9f4d5e51bdb4fdfcd01.setContent(html_c63f24b1fab466cd9d5e24015dcca0a4);
#
#
#
#         marker_a42541c910ed64972771cf6cae032266.bindPopup(popup_d0fb62271fe4e9f4d5e51bdb4fdfcd01)
#         ;
#
#
#
#
#             var marker_1dc6774420dbd4108cd09b6ead2b4008 = L.marker(
#                 [-8.8383, 13.2344],
#                 {}
#             ).addTo(map_ba867efad77a62497f0e168c67d15732);
#
#
#         var popup_3d6d1b790715a36b02db15ad0fd613da = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0773413ab9c03c94f14ca477d9dc23e2 = $(`&lt;div id=&quot;html_0773413ab9c03c94f14ca477d9dc23e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Luanda 8883000.0&lt;/div&gt;`)[0];
#                 popup_3d6d1b790715a36b02db15ad0fd613da.setContent(html_0773413ab9c03c94f14ca477d9dc23e2);
#
#
#
#         marker_1dc6774420dbd4108cd09b6ead2b4008.bindPopup(popup_3d6d1b790715a36b02db15ad0fd613da)
#         ;
#
#
#
#
#             var marker_54e7248b3ec4556bf7983bd4a0629ad9 = L.marker(
#                 [-6.8, 39.2833],
#                 {}
#             ).addTo(map_ba867efad77a62497f0e168c67d15732);
#
#
#         var popup_9f6bfb01f0e48e7ee1d8a16c3f3025a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c13af7dd3776c370abe78a6a06b1f66 = $(`&lt;div id=&quot;html_9c13af7dd3776c370abe78a6a06b1f66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dar es Salaam 7461000.0&lt;/div&gt;`)[0];
#                 popup_9f6bfb01f0e48e7ee1d8a16c3f3025a8.setContent(html_9c13af7dd3776c370abe78a6a06b1f66);
#
#
#
#         marker_54e7248b3ec4556bf7983bd4a0629ad9.bindPopup(popup_9f6bfb01f0e48e7ee1d8a16c3f3025a8)
#         ;
#
#
#
#
#             var marker_99352c97354e0fc88dd003774f55c60a = L.mark

# %% [markdown]
# Add a different type of marker.
#
# More icons include ['bicycle', 'car', 'bus', 'truck', 'motorcycle']

# %%
# Lets add different types of markers for population

for index, location_info in african_cities_pop .iterrows():

    # Population marker
    folium.Marker([location_info.lat, location_info.lng],
                  popup=location_info.population,          # Clicking the icon will show population for that city
                  icon = folium.Icon(icon = "info-sign")).add_to(map)
# Call map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_037163e6b77e54e62d9e166c833c8f40 {
#                     position: relative;
#                     width: 900.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_037163e6b77e54e62d9e166c833c8f40&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_037163e6b77e54e62d9e166c833c8f40 = L.map(
#                 &quot;map_037163e6b77e54e62d9e166c833c8f40&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_037163e6b77e54e62d9e166c833c8f40);
#
#
#
#
#
#             var tile_layer_785801627135c72200d0886390d7e5dc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_037163e6b77e54e62d9e166c833c8f40);
#
#
#             var tile_layer_e7815ebd8e898ac78c1f9f2247122756 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_037163e6b77e54e62d9e166c833c8f40);
#
#
#             var tile_layer_46ccec8f2a1d8d052df8af15e4d5e0f3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_037163e6b77e54e62d9e166c833c8f40);
#
#
#             var tile_layer_e49d0b1fa199112f854e50580ebeeacd = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_037163e6b77e54e62d9e166c833c8f40);
#
#
#             var tile_layer_60021957049e3e754c3bd7a20423a6c0 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_037163e6b77e54e62d9e166c833c8f40);
#
#
#             var tile_layer_c521a8d1963bff2480b12f386022547a = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u

# %% [markdown]
# Enumerate markers using a Carto DB base map style. Loop using itertools.

# %%
# Initiate an enumerated map
enum = folium.Map(location=[5, 24], tiles="CartoDB Positron",
                  zoom_start=3, width=900, height=600,control_scale = True)

for index, location_info in african_cities_pop.iterrows():

    # Population marker
    folium.Marker([location_info.lat, location_info.lng],
                  # popup=location_info.population,
                  icon = plugins.BeautifyIcon(number = location_info.city_ascii,
                                          border_color = "green",
                                          border_width = "2",
                                          background_color = 'yellow',  # Others : "Transparent"
                                          text_color = "purple",
                                            # Try inner_icon_style='margin-top:0px;'
                                          inner_icon_style='font-size:10px;margin-top:1px')
                 ).add_to(enum)

folium.TileLayer('CartoDB positron',name="Light Map",control=False).add_to(enum)

enum
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6f85a4fe7b46799c17e9c3d3a159165 {
#                     position: relative;
#                     width: 900.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6f85a4fe7b46799c17e9c3d3a159165&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6f85a4fe7b46799c17e9c3d3a159165 = L.map(
#                 &quot;map_b6f85a4fe7b46799c17e9c3d3a159165&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b6f85a4fe7b46799c17e9c3d3a159165);
#
#
#
#
#
#             var tile_layer_5d1bf425aaa2d976462221a91101e543 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b6f85a4fe7b46799c17e9c3d3a159165);
#
#
#             var marker_45621154a5284b5c8fc27e25d21587ef = L.marker(
#                 [30.0444, 31.2358],
#                 {}
#             ).addTo(map_b6f85a4fe7b46799c17e9c3d3a159165);
#
#
#             var beautify_icon_0e127e90af0e21b8a53f4af89c094890 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;yellow&quot;, &quot;borderColor&quot;: &quot;green&quot;, &quot;borderWidth&quot;: &quot;2&quot;, &quot;innerIconStyle&quot;: &quot;font-size:10px;margin-top:1px&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: &quot;Cairo&quot;, &quot;textColor&quot;: &quot;purple&quot;}
#             )
#             marker_45621154a5284b5c8fc27e25d21587ef.setIcon(beautify_icon_0e127e90af0e21b8a53f4af89c094890);
#
#
#             var marker_ebdd45623258dc93ebd194a047598658 = L.marker(
#                 [6.45, 3.4],
#                 {}
#             ).addTo(map_b6f85a4fe7b46799c17e9c3d3a159165);
#
#
#             var beautify_icon_0ffab7a3e615d57b09afb25657b59abc = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;yellow&quot;, &quot;borderColor&quot;: &quot;green&quot;, &quot;borderWidth&quot;: &quot;2&quot;, &quot;innerIconStyle&quot;: &quot;font-size:10px;margin-top:1px&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: &quot;Lagos&quot;, &quot;textColor&quot;: &quot;purple&quot;}
#             )
#             marker_ebdd45623258dc93ebd194a047598658.setIcon(beautify_icon_0ffab7a3e615d57b09afb25657b59abc);
#
#
#             var marker_0d2117c0ed5a00f073b725b57b836313 = L.marker(
#                 [-4.3317, 15.3139],
#                 {}
#             ).addTo(map_b6f85a4fe7b46799c17e9c3d3a159165);
#
#
#             var beautify_icon_2097551e5a643b33e71fdfc32a1ccd3e = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;yellow&quot;, &quot;borderColor&quot;: &quot;green&quot;, &quot;borderWidth&quot;: &quot;2&quot;, &quot;innerIconStyle&quot;: &quot;font-size:10px;margin-top:1px&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: &quot;Kinshasa&quot;, &quot;textColor&quot;: &quot;purple&quot;}
#             )
#             marker_0d2117c0ed5a00f073b725b57b836313.setIcon(beautify_icon_2097551e5a643b33e71fdfc32a1ccd3e);
#
#
#             var marker_c6c3fe8a20d0f289b82047677f28c989 = L.marker(
#                 [-8.8383, 13.2344],
#                 {}
#             ).addTo(map_b6f85a4fe7b46799c17e9c3d3a159165);
#
#
#             var beautify_icon_315512e0890ca4ebfd3cb40d6b4fff7e = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;yellow&quot;, &quot;borderColor&quot;: &quot;green&quot;, &quot;borderWidth&quot;: &quot;2&quot;, &quot;innerIconStyle&quot;: &quot;font-size:10px;margin-top:1px&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: &quot;Luanda&quot;, &quot;textColor&quot;: &quot;purple&quot;}
#             )
#             marker_c6c3fe8a20d0f289b82047677f28c989.setIcon(beautify_icon_315512e0890ca4ebfd3cb40d6b4fff7e);
#
#
#             var marker_804aacc9149c1ee2526c90bd70bf493b = L.marker(
#                 [-6.8, 39.2833],
#                 {}
#             ).addTo(map_b6f85a4fe7b46799c17e9c3d3a159165);
#
#
#             var beautify_icon_ee0313a989f6f61b3571e4c7dc70dc11 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;yellow&quot;, &quot;borderColor&quot;: &quot;green&quot;, &quot;borderWi

# %% [markdown]
# Enumerate markers again but loop using itertuples.

# %%
# Initiate an enumerated map
enum = folium.Map(location=[5, 24],
                  tiles=None,   # No basemap
                  zoom_start=3, width=900, height=600,control_scale = True)

# Use itertuple to loop through
for i in african_cities_pop.itertuples():
    folium.Marker([i.lat, i.lng],  # Location
                 popup = i.population,
                 icon=plugins.BeautifyIcon(number = i.iso3,
                                          border_color = "green",
                                          border_width = "1",
                                          text_color = "red",
                                          inner_icon_style='margin-top:0px;')).add_to(enum)

# Call map
enum
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a281f6a8455b38094b1d9a17db465fb {
#                     position: relative;
#                     width: 900.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a281f6a8455b38094b1d9a17db465fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6a281f6a8455b38094b1d9a17db465fb = L.map(
#                 &quot;map_6a281f6a8455b38094b1d9a17db465fb&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_6a281f6a8455b38094b1d9a17db465fb);
#
#
#
#
#
#             var tile_layer_b76090fc06f9432119510c0bde901519 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6a281f6a8455b38094b1d9a17db465fb);
#
#
#             var marker_2208067c670fff2ca18bc4e416303abd = L.marker(
#                 [30.0444, 31.2358],
#                 {}
#             ).addTo(map_6a281f6a8455b38094b1d9a17db465fb);
#
#
#             var beautify_icon_6c6b2305fb0ddf59e2923a0e155edef4 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;green&quot;, &quot;borderWidth&quot;: &quot;1&quot;, &quot;innerIconStyle&quot;: &quot;margin-top:0px;&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: &quot;EGY&quot;, &quot;textColor&quot;: &quot;red&quot;}
#             )
#             marker_2208067c670fff2ca18bc4e416303abd.setIcon(beautify_icon_6c6b2305fb0ddf59e2923a0e155edef4);
#
#
#         var popup_3ed71f9b94d1a80d67c04ed31fb940b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dec88b21d2e573a87ca138741eae070e = $(`&lt;div id=&quot;html_dec88b21d2e573a87ca138741eae070e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;19787000.0&lt;/div&gt;`)[0];
#                 popup_3ed71f9b94d1a80d67c04ed31fb940b6.setContent(html_dec88b21d2e573a87ca138741eae070e);
#
#
#
#         marker_2208067c670fff2ca18bc4e416303abd.bindPopup(popup_3ed71f9b94d1a80d67c04ed31fb940b6)
#         ;
#
#
#
#
#             var marker_920785f2e5d5a0dbb6ed4e4e9e891faf = L.marker(
#                 [6.45, 3.4],
#                 {}
#             ).addTo(map_6a281f6a8455b38094b1d9a17db465fb);
#
#
#             var beautify_icon_41408f0114055596055645ac4d03960b = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;green&quot;, &quot;borderWidth&quot;: &quot;1&quot;, &quot;innerIconStyle&quot;: &quot;margin-top:0px;&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: &quot;NGA&quot;, &quot;textColor&quot;: &quot;red&quot;}
#             )
#             marker_920785f2e5d5a0dbb6ed4e4e9e891faf.setIcon(beautify_icon_41408f0114055596055645ac4d03960b);
#
#
#         var popup_8267302d1b994cd87b161b001b34ad53 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea54e29de056b51a15c1754b78fa5233 = $(`&lt;div id=&quot;html_ea54e29de056b51a15c1754b78fa5233&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;15487000.0&lt;/div&gt;`)[0];
#                 popup_8267302d1b994cd87b161b001b34ad53.setContent(html_ea54e29de056b51a15c1754b78fa5233);
#
#
#
#         marker_920785f2e5d5a0dbb6ed4e4e9e891faf.bindPopup(popup_8267302d1b994cd87b161b001b34ad53)
#         ;
#
#
#
#
#             var marker_e8e8f726da558819e5f7e5b7e5610e62 = L.marker(
#                 [-4.3317, 15.3139],
#                 {}
#             ).addTo(map_6a281f6a8455b38094b1d9a17db465fb);
#
#
#             var beautify_icon_6d78bef1a3c2e4cf4ba6b1a96db6f533 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;green&quot;, &quot;borderWidth&quot;: &quot;1&quot;, &quot;innerIconStyle&quot;: &quot;margin-top:0px;&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: &quot;COD&quot;, &quot;textColor&quot;: &quot;red&quot;}
#             )
#             marker_e8e8f726da558819e5f7e5b7e5610e62.setIcon(beautify_icon_6d78bef1a3c2e4cf4ba6b1a96db6f533);

# %% [markdown]
# **4.3.  Cirle Markers.**
#
# Add a customized circle marker to all the cities. The circle will always maintain the same size irrespective of zoom level.

# %%
# Initiate a second map
map = folium.Map(location=[5, 24], tiles='Stamen Terrain',zoom_start=3, width=900, height=600,control_scale = True)

# add different tiles to map
folium.raster_layers.TileLayer('CartoDB Dark_Matter').add_to(map)
folium.raster_layers.TileLayer('CartoDB Positron').add_to(map)
folium.raster_layers.TileLayer('Open Street Map').add_to(map)

# Loop through each city and add a circle marker.
for index, location_info in african_cities_pop .iterrows():

    # city marker
    folium.CircleMarker([location_info.lat, location_info.lng],
                        radius=10,                                # Pixel value
                        fill=True,
                        color='green',                            # Edge colour
                        fill_color='red',                         # Circle fill colour
                        fill_opacity=0.25 ).add_to(map)

# add layer control to show different maps
folium.LayerControl().add_to(map)
# Show map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e58d4c863f3fe4e431574f52d242d44 {
#                     position: relative;
#                     width: 900.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e58d4c863f3fe4e431574f52d242d44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e58d4c863f3fe4e431574f52d242d44 = L.map(
#                 &quot;map_9e58d4c863f3fe4e431574f52d242d44&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9e58d4c863f3fe4e431574f52d242d44);
#
#
#
#
#
#             var tile_layer_c954652b4e1363ee595408ea84cbf41b = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e58d4c863f3fe4e431574f52d242d44);
#
#
#             var tile_layer_6fc553bfa2857256321ece0bed190e52 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e58d4c863f3fe4e431574f52d242d44);
#
#
#             var tile_layer_68078bd6096259e8025580d9408f494c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e58d4c863f3fe4e431574f52d242d44);
#
#
#             var tile_layer_c7713a99da12445699083c3ab789b805 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e58d4c863f3fe4e431574f52d242d44);
#
#
#             var circle_marker_e869417e50db0b9802e78c00bab2572e = L.circleMarker(
#                 [30.0444, 31.2358],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.25, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9e58d4c863f3fe4e431574f52d242d44);
#
#
#             var circle_marker_edac53da0e0047c80dcc00ee40f81d14 = L.circleMarker(
#                 [6.45, 3.4],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.25, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quo

# %% [markdown]
# Add circle whose sizes are relative to the population, size corresponding to population.

# %%
# Initiate a second map
pop = folium.Map(location=[5, 24], tiles="Stamen Toner" ,zoom_start=3, width=900, height=600,control_scale = True)

# add different tiles to map
folium.raster_layers.TileLayer('CartoDB Dark_Matter').add_to(pop)
folium.raster_layers.TileLayer('Stamen Toner').add_to(pop)
folium.raster_layers.TileLayer('CartoDB Positron').add_to(pop)
folium.raster_layers.TileLayer('Open Street Map').add_to(pop)

# Loop through each city and add a circle marker.
for index, location_info in african_cities_pop.iterrows():

    # city marker
    folium.Circle([location_info.lat, location_info.lng],
                        radius=location_info.population/30,                                # Raduis in meters.
                        fill=True,
                        color='green',
                        fill_color='red',
                        fill_opacity=0.25 ).add_to(pop)

# add layer control to show different maps
folium.LayerControl().add_to(pop)

# Show map
pop
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bcc2fa6adbced620fed907912a145b9d {
#                     position: relative;
#                     width: 900.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bcc2fa6adbced620fed907912a145b9d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bcc2fa6adbced620fed907912a145b9d = L.map(
#                 &quot;map_bcc2fa6adbced620fed907912a145b9d&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_bcc2fa6adbced620fed907912a145b9d);
#
#
#
#
#
#             var tile_layer_70d3106b6b9646fe6039d7fd026dec01 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bcc2fa6adbced620fed907912a145b9d);
#
#
#             var tile_layer_5fa764669028ac92e073a0156612772a = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bcc2fa6adbced620fed907912a145b9d);
#
#
#             var tile_layer_6ec0941e1fd07d2c57fcce7a5dcaed67 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bcc2fa6adbced620fed907912a145b9d);
#
#
#             var tile_layer_6e2b018839b8d5bec54cbcb958c3aed4 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bcc2fa6adbced620fed907912a145b9d);
#
#
#             var tile_layer_1953702d9204069258f38dc33ded9e21 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bcc2fa6adbced620fed907912a145b9d);
#
#
#             var circle_d4daafea3cae2f7bfc21dbd138535b4

# %% [markdown]
# **4.4. GeoJson layer.**
#
# Overlay multiple layers including : countries geojson, population circle marker and city layer.

# %%
# Add multiple layers , countries layer, population layer , and city layer.

map = folium.Map(location=[5, 24], zoom_start=3, width=900, height=600,control_scale = True)

# Add countries geojson layer
folium.GeoJson(ctry, name="African Countries").add_to(map)


# Add basemaps
folium.raster_layers.TileLayer('CartoDB Positron').add_to(map)
folium.raster_layers.TileLayer('Open Street Map').add_to(map)


# Add population layer
# Loop through each city and add a circle marker.
for index, location_info in african_cities_pop.iterrows():

    # city population marker
    folium.Circle([location_info.lat, location_info.lng],
                        radius=location_info.population/30,                # Radius in meters.
                        popup=location_info.population,
                        fill=True,
                        color='green',
                        fill_color='red',
                                          fill_opacity=0.25).add_to(map)


# Add cities layer
# Loop through each city and add a circle marker.
for index, location_info in african_cities_pop .iterrows():

    # city marker
    folium.CircleMarker([location_info.lat, location_info.lng],
                        popup=location_info.city_ascii,
                        radius=10,                                # Pixel value
                        fill=True,
                        color='green',                            # Edge colour
                        fill_color='red',                         # Circle fill colour
                        fill_opacity=0.25).add_to(map)


# Add layer control
folium.LayerControl().add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a425cffa05a2febc96c72870744dec20 {
#                     position: relative;
#                     width: 900.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a425cffa05a2febc96c72870744dec20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a425cffa05a2febc96c72870744dec20 = L.map(
#                 &quot;map_a425cffa05a2febc96c72870744dec20&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_a425cffa05a2febc96c72870744dec20);
#
#
#
#
#
#             var tile_layer_f949c887787503282428b6949127485e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a425cffa05a2febc96c72870744dec20);
#
#
#
#         function geo_json_f039522b4ebcc06340d4ae75202ef43c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f039522b4ebcc06340d4ae75202ef43c = L.geoJson(null, {
#                 onEachFeature: geo_json_f039522b4ebcc06340d4ae75202ef43c_onEachFeature,
#
#         });
#
#         function geo_json_f039522b4ebcc06340d4ae75202ef43c_add (data) {
#             geo_json_f039522b4ebcc06340d4ae75202ef43c
#                 .addData(data)
#                 .addTo(map_a425cffa05a2febc96c72870744dec20);
#         }
#             geo_json_f039522b4ebcc06340d4ae75202ef43c_add({&quot;bbox&quot;: [-17.625043, -34.819166, 51.13387, 37.349994], &quot;features&quot;: [{&quot;bbox&quot;: [29.024926, -4.499983, 30.752263, -2.348487], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[29.339998, -4.499983], [29.276384, -3.293907], [29.024926, -2.839258], [29.632176, -2.917858], [29.938359, -2.348487], [30.469696, -2.413858], [30.527677, -2.807632], [30.743013, -3.034285], [30.752263, -3.35933], [30.50556, -3.568567], [30.116333, -4.090138], [29.753512, -4.452389], [29.339998, -4.499983]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;abbrev&quot;: &quot;Bur.&quot;, &quot;abbrev_len&quot;: 4, &quot;adm0_a3&quot;: &quot;BDI&quot;, &quot;adm0_a3_is&quot;: &quot;BDI&quot;, &quot;adm0_a3_un&quot;: -99, &quot;adm0_a3_us&quot;: &quot;BDI&quot;, &quot;adm0_a3_wb&quot;: -99, &quot;adm0_dif&quot;: 0, &quot;admin&quot;: &quot;Burundi&quot;, &quot;brk_a3&quot;: &quot;BDI&quot;, &quot;brk_diff&quot;: 0, &quot;brk_group&quot;: null, &quot;brk_name&quot;: &quot;Burundi&quot;, &quot;continent&quot;: &quot;Africa&quot;, &quot;economy&quot;: &quot;7. Least developed region&quot;, &quot;featurecla&quot;: &quot;Admin-0 country&quot;, &quot;filename&quot;: &quot;BDI.geojson&quot;, &quot;fips_10&quot;: null, &quot;formal_en&quot;: &quot;Republic of Burundi&quot;, &quot;formal_fr&quot;: null, &quot;gdp_md_est&quot;: 3102.0, &quot;gdp_year&quot;: -99, &quot;geou_dif&quot;: 0, &quot;geounit&quot;: &quot;Burundi&quot;, &quot;gu_a3&quot;: &quot;BDI&quot;, &quot;homepart&quot;: 1, &quot;income_grp&quot;: &quot;5. Low income&quot;, &quot;iso_a2&quot;: &quot;BI&quot;, &quot;iso_a3&quot;: &quot;BDI&quot;, &quot;iso_n3&quot;: &quot;108&quot;, &quot;labelrank&quot;: 6, &quot;lastcensus&quot;: 2008, &quot;level&quot;: 2, &quot;long_len&quot;: 7, &quot;mapcolor13&quot;: 8, &quot;mapcolor7&quot;: 2, &quot;mapcolor8&quot;: 2, &quot;mapcolor9&quot;: 5, &quot;name&quot;: &quot;Burundi&quot;, &quot;name_alt&quot;: null, &quot;name_len&quot;: 7, &quot;name_long&quot;: &quot;Burundi&quot;, &quot;name_sort&quot;: &quot;Burundi&quot;, &quot;note_adm0&quot;: null, &quot;note_brk&quot;: null, &quot;pop_est&quot;: 8988091, &quot;pop_year&quot;: -99, &quot;postal&quot;: &quot;BI&quot;, &quot;region_un&quot;: &quot;Africa&quot;, &quot;region_wb&quot;: &quot;Sub-Saharan Africa&quot;, &quot;scalerank&quot;: 1, &quot;sov_a3&quot;: &quot;BDI&quot;, &quot;sovereignt&quot;: &quot;Burundi&quot;, &quot;su_a3&quot;: &quot;BDI&quot;, &quot;su_dif&quot;: 0, &quot;subregion&quot;: &quot;Eastern Africa&quot;, &quot;subunit&quot;: &quot;Burundi&quot;, &quot;tiny&quot;: -99, &quot;type&quot;: &quot;Sovereign country&quot;, &quot;un_a3&quot;: &quot;108&quot;, &quot;wb_a2&quot;: &quot;BI&quot;, &quot;wb_a3&quot;: &quot;BDI&quot;, &quot;wikipedia&quot;: -99, &quot;woe_id&quot;: -99}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [0.772336, 6.142158, 3.797112, 12.235636], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[2.691702, 6.258817], [1.865241, 6.142158], [1.618951, 6.832038], [1.664478, 9.12859], [1.463043, 9.334624], [1.425061, 9.825395], [1.077795, 10.175607], [0.772336, 10.470808], [0.899563, 10.997339], [1.24347, 11.110511], [1.447178, 11.547719], [1.935986, 11.64115], [2.154474, 11.94015], [2.490164, 12.233052], [2.848643, 12.235636], [3.61118, 11.660167], [3.572216, 11.327939], [3.797112, 10.734746], [

# %% [markdown]
# **4.5. Minimap.**
#
# A minimalistic map than full scale map that removes objects and details but show essential information. The show location.

# %%
# Add a minimap to cities data at the bottom of the main map.

# Initiate a second map
map = folium.Map(location=[5, 24], zoom_start=3, width=900, height=600,control_scale = True)

# Loop through each city and add a circle marker.
for index, location_info in african_cities_pop.iterrows():

    # city marker
    folium.Marker([location_info.lat, location_info.lng],
                        popup=location_info.city_ascii,
                        icon=folium.Icon(color='green', icon = "info-sign")).add_to(map)

# Add mini map
plugins.MiniMap().add_to(map)

# Add scroll zoom toggler to map
plugins.ScrollZoomToggler().add_to(map)

# Add full screen button to map
plugins.Fullscreen(position='topright').add_to(map)

# Add layer control to show different maps
folium.LayerControl().add_to(map)

# Show map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f605c20b8e698180fbb48b24cb6d3376 {
#                     position: relative;
#                     width: 900.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
#
#             &lt;style&gt;
#                 #scroll_zoom_toggler_5ccca2d1d7f2ffcc71acd7774252dec3 {
#                     position:absolute;
#                     width:35px;
#                     bottom:10px;
#                     height:35px;
#                     left:10px;
#                     background-color:#fff;
#                     text-align:center;
#                     line-height:35px;
#                     vertical-align: middle;
#                     }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f605c20b8e698180fbb48b24cb6d3376&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;scroll_zoom_toggler_5ccca2d1d7f2ffcc71acd7774252dec3&quot;
#                  alt=&quot;scroll&quot;
#                  src=&quot;https://cdnjs.cloudflare.com/ajax/libs/ionicons/2.0.1/png/512/arrow-move.png&quot;
#                  style=&quot;z-index: 999999&quot;
#                  onclick=&quot;map_f605c20b8e698180fbb48b24cb6d3376.toggleScroll()&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f605c20b8e698180fbb48b24cb6d3376 = L.map(
#                 &quot;map_f605c20b8e698180fbb48b24cb6d3376&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f605c20b8e698180fbb48b24cb6d3376);
#
#
#
#
#
#             var tile_layer_f85168618ee1310bdd17fa16610bfa02 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f605c20b8e698180fbb48b24cb6d3376);
#
#
#             var marker_681ef324443061ecd5cbe1a85134ce08 = L.marker(
#                 [30.0444, 31.2358],
#                 {}
#             ).addTo(map_f605c20b8e698180fbb48b24cb6d3376);
#
#
#             var icon_aa7e96b4557875b73e0312070df840bb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_681ef324443061ecd5cbe1a85134ce08.setIcon(icon_aa7e96b4557875b73e0312070df840bb);
#
#
#         var popup_1e98bd55ce6b2207d42c77a23f3e2e2c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e843a3e41e3df667cd5348472c7d2f4 = $(`&lt;div id=&quot;html_8e843a3e41e3df667cd5348472c7d2f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cairo&lt;/div&gt;`)[0];
#                 popup_1e98bd55ce6b2207d42c77a23f3e2e2c.setContent(html_8e843a3e41e3df667cd5348472c7d2f4);
#
#
#
#         marker_681ef324443061ecd5cbe1a85134ce08.bindPopup(popup_1e98bd55ce6b2207d42c77a23f3e2e2c)
#         ;
#
#
#
#
#             var marker_ae08a9c6c5e0de1da289361bc25a4220 = L.marker(
#                 [6.45, 3.4],
#                 {}
#             ).addTo(map_f605c20b8e698180fbb48b24cb6d3376);
#
#
#             var icon_de7cc2f9e7527f8ed9a2e27b6f88b432 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ae08a9c6c5e0de1da289361bc25a4220.setIcon(icon_de7cc2f9e7527f8ed9a2e27b6f88b432);
#
#
#         var popup_12d9e8c30ebc77dcd0fc4cb30b382118 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c2f89370e3a023651f5b895262d1bd5 = $(`&lt;div id=&quot;html_4c2f89370e3a023651f5b895262d1bd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lagos&lt;/div&gt;`)[0];
#                 popup_12d9e8c30ebc77dcd0fc4cb30b382118.setContent(html_4c2f89370e3a023651f5b895262d1bd5);
#
#
#
#         marker_ae08a9c6c5e0de1da289361bc25a4220.bindPopup(popup_12d9e8c30ebc77dcd0fc4cb30b382118)
#         ;
#
#
#
#
#             var marker_701b4b3692ce3561eaaabd8c12eb6196 = L.marker(
#                 [-4.3317,

# %% [markdown]
# **4.6. Search bar.**
#
# Creates a map with search box located inside the map and allows user to type and identify names of places across the globe. The map automatically zooms to that location when clicked.

# %%
# Initiate a second map
search = folium.Map(location=[5, 24], zoom_start=3, width=900, height=600,control_scale = True)

# Add plugin
plugins.Geocoder().add_to(search)

# Call map
search
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_235239013e3f8f2a7940e867e3e196a2 {
#                     position: relative;
#                     width: 900.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_235239013e3f8f2a7940e867e3e196a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_235239013e3f8f2a7940e867e3e196a2 = L.map(
#                 &quot;map_235239013e3f8f2a7940e867e3e196a2&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_235239013e3f8f2a7940e867e3e196a2);
#
#
#
#
#
#             var tile_layer_e5518561d9afdc947a6a6be9f3d072e2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_235239013e3f8f2a7940e867e3e196a2);
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: false, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_235239013e3f8f2a7940e867e3e196a2.setView(e.geocode.center, 11);
#             }).addTo(map_235239013e3f8f2a7940e867e3e196a2);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **4.7. Terminator.**
#
# Terminator shows the separation between the day and the night at the exact moment the map was created.

# %%
# Initiate a second map
term = folium.Map(location=[5, 24], zoom_start=3, width=900, height=600,control_scale = True)

# Add plugin
plugins.Terminator().add_to(search)

# Call map
term
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f85be702ed7083a55a91f63d3fbef54 {
#                     position: relative;
#                     width: 900.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f85be702ed7083a55a91f63d3fbef54&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f85be702ed7083a55a91f63d3fbef54 = L.map(
#                 &quot;map_4f85be702ed7083a55a91f63d3fbef54&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4f85be702ed7083a55a91f63d3fbef54);
#
#
#
#
#
#             var tile_layer_5fe13c046bed2c927a2f11f1e045a8a7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4f85be702ed7083a55a91f63d3fbef54);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **4.8. Routes.**
#
# Using a line lets connect seven most popular cities on the map.

# %%
# Filter the most populous cities , more than 5m people
largest = african_cities_pop[african_cities_pop.population > 5000000].head(6)

# Extract geometries x, y coordinates
coord = list(zip(largest.lat, largest.lng))

# Initialise map
route = folium.Map([5, 24], zoom_start=3, tiles ='CartoDB Positron',control_scale = True)

# Add basemap
folium.raster_layers.TileLayer('CartoDB Positron').add_to(route)

# Add route to search map
folium.PolyLine(coord).add_to(route)

# Add layer control
folium.LayerControl().add_to(route)

# Call map
route
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e737047f1bd17969d52ed7cb040bcc6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e737047f1bd17969d52ed7cb040bcc6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e737047f1bd17969d52ed7cb040bcc6 = L.map(
#                 &quot;map_0e737047f1bd17969d52ed7cb040bcc6&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0e737047f1bd17969d52ed7cb040bcc6);
#
#
#
#
#
#             var tile_layer_6603754261f3173e76816e95da11fa72 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0e737047f1bd17969d52ed7cb040bcc6);
#
#
#             var tile_layer_69d98649cffcfe0bb8bf499430807028 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0e737047f1bd17969d52ed7cb040bcc6);
#
#
#             var poly_line_6d8ec026c3f5023722711af23b1f8119 = L.polyline(
#                 [[30.0444, 31.2358], [6.45, 3.4], [-4.3317, 15.3139], [-8.8383, 13.2344], [-6.8, 39.2833], [15.6031, 32.5265]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0e737047f1bd17969d52ed7cb040bcc6);
#
#
#             var layer_control_52d891884fca441ad030152b8edeb8d1 = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_69d98649cffcfe0bb8bf499430807028,
#                 },
#                 overlays :  {
#                 },
#             };
#             L.control.layers(
#                 layer_control_52d891884fca441ad030152b8edeb8d1.base_layers,
#                 layer_control_52d891884fca441ad030152b8edeb8d1.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_0e737047f1bd17969d52ed7cb040bcc6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **4.9. Ant Routes.**

# %%
# Add ant paths route to our large cities

# Initialise map
ant_path = folium.Map([5, 24], tiles = 'CartoDB Positron', zoom_start=4)

# Add path
plugins.AntPath(coord).add_to(ant_path)

ant_path
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50c1b7e7c38c8bbeb5d2d5d427381905 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50c1b7e7c38c8bbeb5d2d5d427381905&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50c1b7e7c38c8bbeb5d2d5d427381905 = L.map(
#                 &quot;map_50c1b7e7c38c8bbeb5d2d5d427381905&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8cb849ecdc1b6099947a87c52d15d951 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_50c1b7e7c38c8bbeb5d2d5d427381905);
#
#
#             ant_path_11d27c2b4fe706be73e1b2bdc61a6da8 = L.polyline.antPath(
#               [[30.0444, 31.2358], [6.45, 3.4], [-4.3317, 15.3139], [-8.8383, 13.2344], [-6.8, 39.2833], [15.6031, 32.5265]],
#               {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0000FF&quot;, &quot;dashArray&quot;: [10, 20], &quot;dashOffset&quot;: null, &quot;delay&quot;: 400, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;hardwareAcceleration&quot;: false, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;paused&quot;: false, &quot;pulseColor&quot;: &quot;#FFFFFF&quot;, &quot;reverse&quot;: false, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#         ).addTo(map_50c1b7e7c38c8bbeb5d2d5d427381905);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **4.10. Cluster Markers.**
#
# Cluster markers group toether multiple markers based on zoom level.

# %%
 # Get x and y coordinate for each point and store them in new columns X and Y.
african_cities_pop['X'] = african_cities_pop['geometry'].apply(lambda geom: geom.x)
african_cities_pop['Y'] = african_cities_pop['geometry'].apply(lambda geom: geom.y)

# Create a list of coordinate pairs,
locations = list(zip(african_cities_pop['Y'], african_cities_pop['X']))

# initialise map
cluster = folium.Map(location=[5, 24], zoom_start=3, width=900, height=600,control_scale = True)

# Add cluster
plugins.MarkerCluster(locations).add_to(cluster)
cluster
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_451e96b2e4ac3da53fd59bddfb92d1d0 {
#                     position: relative;
#                     width: 900.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_451e96b2e4ac3da53fd59bddfb92d1d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_451e96b2e4ac3da53fd59bddfb92d1d0 = L.map(
#                 &quot;map_451e96b2e4ac3da53fd59bddfb92d1d0&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_451e96b2e4ac3da53fd59bddfb92d1d0);
#
#
#
#
#
#             var tile_layer_c81fa63cc461db1ad58fed0cf2bdfb51 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_451e96b2e4ac3da53fd59bddfb92d1d0);
#
#
#             var marker_cluster_94b760e0877fa953982904d5544add69 = L.markerClusterGroup(
#                 {}
#             );
#             map_451e96b2e4ac3da53fd59bddfb92d1d0.addLayer(marker_cluster_94b760e0877fa953982904d5544add69);
#
#
#             var marker_8f58a77c2b505b96bb151e099c0e9121 = L.marker(
#                 [30.0444, 31.2358],
#                 {}
#             ).addTo(marker_cluster_94b760e0877fa953982904d5544add69);
#
#
#             var marker_9e60dfb49b291af35ed1d875909b5584 = L.marker(
#                 [6.45, 3.4],
#                 {}
#             ).addTo(marker_cluster_94b760e0877fa953982904d5544add69);
#
#
#             var marker_74666883ae8ecbf05c37d752410f8323 = L.marker(
#                 [-4.3317, 15.3139],
#                 {}
#             ).addTo(marker_cluster_94b760e0877fa953982904d5544add69);
#
#
#             var marker_23964cf2b154408cc437e0aa91ae3412 = L.marker(
#                 [-8.8383, 13.2344],
#                 {}
#             ).addTo(marker_cluster_94b760e0877fa953982904d5544add69);
#
#
#             var marker_9ac7b55d10d31741d3b02e37b898be2d = L.marker(
#                 [-6.8, 39.2833],
#                 {}
#             ).addTo(marker_cluster_94b760e0877fa953982904d5544add69);
#
#
#             var marker_bc261cf63478ec101f3c131504a38b43 = L.marker(
#                 [15.6031, 32.5265],
#                 {}
#             ).addTo(marker_cluster_94b760e0877fa953982904d5544add69);
#
#
#             var marker_bb25ef576278e90280bd931285210588 = L.marker(
#                 [29.987, 31.2118],
#                 {}
#             ).addTo(marker_cluster_94b760e0877fa953982904d5544add69);
#
#
#             var marker_e9e3827db871065518a95a72c295e615 = L.marker(
#                 [-1.2864, 36.8172],
#                 {}
#             ).addTo(marker_cluster_94b760e0877fa953982904d5544add69);
#
#
#             var marker_fe0c13ceef44921edafa7f3340d00d0d = L.marker(
#                 [5.3364, -4.0267],
#                 {}
#             ).addTo(marker_cluster_94b760e0877fa953982904d5544add69);
#
#
#             var marker_22a02e0e3a45bbb8ac639490117efcbb = L.marker(
#                 [31.2, 29.9167],
#                 {}
#             ).addTo(marker_cluster_94b760e0877fa953982904d5544add69);
#
#
#             var marker_0f08c94b1d89975eabe68104bb8e7647 = L.marker(
#                 [-26.2044, 28.0416],
#                 {}
#             ).addTo(marker_cluster_94b760e0877fa953982904d5544add69);
#
#
#             var marker_298062ccd0299c8c4a5aba6e553022a6 = L.marker(
#                 [12.0, 8.5167],
#                 {}
#             ).addTo(marker_cluster_94b760e0877fa953982904d5544add69);
#
#
#             var marker_db935e7eb7072336ad099e44e49e000b = L.marker(
#                 [36.7764, 3.0586],
#                 {}
#             ).addTo(marker_cluster_94b760e0877fa953982904d5544add69);
#
#
#             var marker_4f50a3e21403e37f1fd1616db8b3f206 = L.marker(
#                 [9.0272, 38.7369],
#                 {}
#             ).addTo(marker_cluster_94b760e0877fa953982904d5544add69);
#
#
#             var marker_41174818dd506f7ffbea42ad1f667662 = L.marker(
#                 [-18.9386, 47.5214],
#                 {}
#             ).addTo(marker_cluster_94b760e0877fa953982904d5544add69);
#
#
#             var marker_f83c5228d03d6afc746d210fe189d9ba = L.marker(
#                 [7.3964, 3.9167],
#                 {}
#             ).addTo(marker_cluster_94b760e0877fa953982904d5544add69);
#
#
#             var marker_6b66e22d1ef3b3689

# %% [markdown]
# **4.11. Heatmaps.**
#
# They show georaphical clustering of a certaing phenomenon by using different levels of concentration of an entity.

# %%
# A heatmap of african cities location

# Make an empty map
heat = folium.Map(location=[5, 24], zoom_start=3, width=900, height=600,control_scale = True)

# Add marker to each location
plugins.HeatMap(locations).add_to(heat)


# Call map
heat
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84d48b50fafaae4b3873db2ae942e659 {
#                     position: relative;
#                     width: 900.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84d48b50fafaae4b3873db2ae942e659&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84d48b50fafaae4b3873db2ae942e659 = L.map(
#                 &quot;map_84d48b50fafaae4b3873db2ae942e659&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_84d48b50fafaae4b3873db2ae942e659);
#
#
#
#
#
#             var tile_layer_d0db16c2864f901eb094dc85e19704bc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_84d48b50fafaae4b3873db2ae942e659);
#
#
#             var heat_map_436e1abbcfbdec1666e337496ce4ee30 = L.heatLayer(
#                 [[30.0444, 31.2358], [6.45, 3.4], [-4.3317, 15.3139], [-8.8383, 13.2344], [-6.8, 39.2833], [15.6031, 32.5265], [29.987, 31.2118], [-1.2864, 36.8172], [5.3364, -4.0267], [31.2, 29.9167], [-26.2044, 28.0416], [12.0, 8.5167], [36.7764, 3.0586], [9.0272, 38.7369], [-18.9386, 47.5214], [7.3964, 3.9167], [12.3686, -1.5275], [3.8578, 11.5181], [15.6167, 32.48], [5.6037, -0.187], [-17.8292, 31.0522], [2.0408, 45.3425], [6.6833, -1.6167], [12.6458, -7.9922], [-4.2667, 15.2833], [-15.4167, 28.2833], [9.538, -13.6773], [0.3136, 32.5811], [5.1167, 7.3667], [-26.2678, 27.8586], [9.0556, 7.4914], [-25.9153, 32.5764], [14.7319, -17.4572], [-1.9536, 30.0606], [32.8752, 13.1875], [12.11, 15.05], [18.0858, -15.9785], [36.8008, 10.18], [13.5086, 2.1111], [6.3106, -10.8047], [15.3333, 38.9167], [8.4833, -13.2331], [4.3732, 18.5628], [6.1319, 1.2228], [0.3901, 9.4544], [-13.9833, 33.7833], [6.402, 2.518], [-25.7464, 28.1881], [-3.3825, 29.3611], [34.0253, -6.8361], [11.595, 43.1481], [-33.925, 18.425], [-6.1835, 35.746], [11.8592, -15.5956], [4.85, 31.6], [6.8161, -5.2742], [-29.31, 27.48], [-22.57, 17.0836], [6.4833, 2.6167], [-29.1, 26.2167], [-24.6569, 25.9086], [3.7521, 8.7737], [-26.3208, 31.1617], [-3.4283, 29.925], [13.4531, -16.5775], [-26.4465, 31.2064], [26.0928, -10.6089]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             ).addTo(map_84d48b50fafaae4b3873db2ae942e659);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **4.12. Choropleth Map.**
#
# Lets plot choropleth map

# %%
# First let do some data scrubbing , enhances accuracy, consistency , and reliability.

# Create a unique column for each feature in africa data, this will be required
# by folium as a unique identifier for each feature
africa['geo_id'] = africa.index.astype(str)

# Select needed column
africa_subset = africa[['geo_id', 'pop_est', 'geometry']]
africa_subset.head()

# Convert to geo-json file
africa_pop = africa_subset.to_json()
# Out:
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Plot choropleth with a mouse position cursor showing coordinates at the top left corner.

# Create map instance
choro = folium.Map([5, 24], tiles = 'CartoDB Positron', zoom_start = 3)

# Interactive choropleth map
folium.Choropleth(geo_data = africa_pop, # A geo_json  file
                 name = "African Countries Population",
                 data = africa_subset,  # A geodataframe
                 columns = ['geo_id', 'pop_est'],
                 key_on = 'feature.id',
                  #bins = 5,                # Number of equal bins
                  bins = [-100, 10000000, 40000000, 60000000, 100000000, 200000000],
                 fill_color = 'YlOrRd',     # Colour scheme "BuPu",
                 fill_opacity = 0.5,        # Polygon transparency ratio
                 line_opacity = 0.5,        # Line transparency
                 line_color='black',     # Borders colour
                 legend_name = 'Population',
                  smooth_factor = 1.0,
                 highlight = True        # Will highlihgt polygon when hovering
                 ).add_to(choro)

# Add mouse position, format to two decimal places
formatter = "function(num) {return L.Util.formatNum(num, 2) + ' º ';};"

plugins.MousePosition(
    position="topleft",
    separator="  ,  ",
    empty_string="NaN",
    lng_first=True,
    num_digits=20,
    prefix="Coordinates:",
    lat_formatter=formatter,
    lng_formatter=formatter,
).add_to(choro)

# layer control to turn choropleth on or off
folium.LayerControl().add_to(choro)

# Call map
choro
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce6931bfd36f86fa73ced84f378579be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce6931bfd36f86fa73ced84f378579be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce6931bfd36f86fa73ced84f378579be = L.map(
#                 &quot;map_ce6931bfd36f86fa73ced84f378579be&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ffa8e09f0c854af3421b3f2b8547d41 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ce6931bfd36f86fa73ced84f378579be);
#
#
#             var choropleth_aab3406981ccfdb29eda8d2de9036eda = L.featureGroup(
#                 {}
#             ).addTo(map_ce6931bfd36f86fa73ced84f378579be);
#
#
#         function geo_json_15b1b478dbc89cfb300dbc2312c3cdc3_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;6&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;28&quot;: case &quot;31&quot;: case &quot;35&quot;: case &quot;39&quot;: case &quot;40&quot;: case &quot;42&quot;: case &quot;43&quot;: case &quot;44&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;4&quot;: case &quot;12&quot;: case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;32&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;47&quot;: case &quot;48&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fecc5c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_15b1b478dbc89cfb300dbc2312c3cdc3_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_15b1b478dbc89cfb300dbc2312c3cdc3_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_15b1b478dbc89cfb300dbc2312c3cdc3.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_15b1b478dbc89cfb300dbc2312c3cdc3_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_15b1b478dbc89cfb300dbc2312c3cdc3 = L.geoJson(null, {
#                 smoothFactor: 1.0,
#                 onEachFeature: geo_json_15b1b478dbc89cfb300dbc2312c3cdc3_onEachFeature,
#
#                 style: geo_json_15b1b478dbc89cfb300dbc2312c3cdc3_styler,
#         });
#
#         function geo_json_15b1b478dbc89cfb300dbc2312c3cdc3_add (data) {
#             geo_json_15b1b478dbc89cfb300dbc2312c3cdc3
#                 .addData(data)
#                 .addTo(choropleth_aab3406981ccfdb29eda8d2de9036eda);
#         }
#             geo_json_15b1b478dbc89cfb300dbc2312c3cdc3_add({&quot;features&quot;: [{&quot;ge

# %% [markdown]
# **4.13. Coordinates Tool.**
#
# This feature allows users to click any position on the map and the map will display latitude & longitude information.**bold text**

# %%
# Initilise map
map_lat_long = folium.Map(location=[5, 24], zoom_start=4)

# add latitude and longitude tool to map
map_lat_long.add_child(folium.LatLngPopup())

# display map
map_lat_long
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff1a073e7fffd9e9c0f197cb339bc102 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff1a073e7fffd9e9c0f197cb339bc102&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff1a073e7fffd9e9c0f197cb339bc102 = L.map(
#                 &quot;map_ff1a073e7fffd9e9c0f197cb339bc102&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae9c49ca4e96690b5770ec10b9258711 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ff1a073e7fffd9e9c0f197cb339bc102);
#
#
#                 var lat_lng_popup_24cca37ff70d54110d870be27ee38e56 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_24cca37ff70d54110d870be27ee38e56
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_ff1a073e7fffd9e9c0f197cb339bc102);
#                     }
#                 map_ff1a073e7fffd9e9c0f197cb339bc102.on(&#x27;click&#x27;, latLngPop);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **4.14. Measure Tool.**
#
# Two points will be selected on the map and the distance between them output on the map canvas.

# %%
# Initialise map
measure_dist = folium.Map([5, 24], zoom_start=4)

# measure control
measure_control = plugins.MeasureControl(position='topright',
                                         active_color='blue',
                                         completed_color='red',
                                         primary_length_unit='kilometers')

# add measure control to map
measure_dist .add_child(measure_control)

# Call map to display
measure_dist
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_446ef6f1ad7b59a5d84e958f12403f99 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_446ef6f1ad7b59a5d84e958f12403f99&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_446ef6f1ad7b59a5d84e958f12403f99 = L.map(
#                 &quot;map_446ef6f1ad7b59a5d84e958f12403f99&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1dcd558bb13b96f6bea8bc2175145459 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_446ef6f1ad7b59a5d84e958f12403f99);
#
#
#             var measure_control_dbcd264ca65433e70ea3f1760dd6ff87 = new L.Control.Measure(
#                 {&quot;activeColor&quot;: &quot;blue&quot;, &quot;completedColor&quot;: &quot;red&quot;, &quot;position&quot;: &quot;topright&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;kilometers&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_446ef6f1ad7b59a5d84e958f12403f99.addControl(measure_control_dbcd264ca65433e70ea3f1760dd6ff87);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **4.15. Dual Map.**

# %%
# dual map
map_dual = plugins.DualMap(location=[5, 24], tiles=None, zoom_start=4)

# map tiles
folium.TileLayer('Stamen Terrain').add_to(map_dual)
folium.TileLayer('CartoDB Positron').add_to(map_dual)

# add layer control to maps
folium.LayerControl().add_to(map_dual)

# display map(s)
map_dual
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c24857552c61f179584776010567c7c3 {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58335f1f830ade513f70b581cd7c554d {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 100.0%;
#                     left: 50.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/jieter/Leaflet.Sync/L.Map.Sync.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c24857552c61f179584776010567c7c3&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58335f1f830ade513f70b581cd7c554d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c24857552c61f179584776010567c7c3 = L.map(
#                 &quot;map_c24857552c61f179584776010567c7c3&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4dead1ded205b36ee7b94f402dbfa3c = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c24857552c61f179584776010567c7c3);
#
#
#             var tile_layer_a13d91f47e0fc38ba504bbb97eb9dda9 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c24857552c61f179584776010567c7c3);
#
#
#             var layer_control_8b5c97d5ab956e03ef0c02c21a6b68ed = {
#                 base_layers : {
#                     &quot;stamenterrain&quot; : tile_layer_e4dead1ded205b36ee7b94f402dbfa3c,
#                     &quot;cartodbpositron&quot; : tile_layer_a13d91f47e0fc38ba504bbb97eb9dda9,
#                 },
#                 overlays :  {
#                 },
#             };
#             L.control.layers(
#                 layer_control_8b5c97d5ab956e03ef0c02c21a6b68ed.base_layers,
#                 layer_control_8b5c97d5ab956e03ef0c02c21a6b68ed.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_c24857552c61f179584776010567c7c3);
#             tile_layer_a13d91f47e0fc38ba504bbb97eb9dda9.remove();
#
#
#             var map_58335f1f830ade513f70b581cd7c554d = L.map(
#                 &quot;map_58335f1f830ade513f70b581cd7c554d&quot;,
#                 {
#                     center: [5.0, 24.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             map_c24857552c61f179584776010567c7c3.sync(map_58335f1f830ade513f70b581cd7c554d);
#             map_58335f1f830ade513f70b581cd7c554d.sync(map_c24857552c61f179584776010567c7c3);
#
#
#             var tile_layer_33fc90411c0c416bb5ad890f406f2c4e = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons

# %% [markdown]
# # 5. References.
#
# 1. African Countries geojson - https://cartographyvectors.com/map/6-africa-outline-with-countries
# 2. World Cities Population data - https://simplemaps.com/data/world-cities
